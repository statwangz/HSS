# %%
setwd("/import/home/share/zw/HSS")
getwd()
# Out:
# [1] "/import/home/share/zw/HSS"

# %%
# install.packages("devtools")
devtools::install_github("statwangz/HSS")
library(HSS)
# Out:
# Downloading GitHub repo statwangz/HSS@HEAD
# stringi (1.7.5 -> 1.7.6) [CRAN]
# dtplyr  (1.2.0 -> 1.2.1) [CRAN]
# Installing 2 packages: stringi, dtplyr
#
# Warning message in i.p(...):
# “installation of package ‘stringi’ had non-zero exit status”
# ✔  checking for file ‘/tmp/Rtmppp4lSx/remotes8f324940e04d/statwangz-HSS-97fab89/DESCRIPTION’ (693ms)
# ─  preparing ‘HSS’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
#      NB: this package now depends on R (>= 3.5.0)
#      WARNING: Added dependency on R >= 3.5.0 because serialized objects in  serialize/load version 3 cannot be read in older versions of R.  File(s) containing such objects: ‘HSS/data/trait_info.rda’
# ─  building ‘HSS_0.0.0.9000.tar.gz’
# Loading required package: tidyverse
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: genio

# %%
# trait information
data(trait_info)
trait_info

trait_name <- trait_info$Trait
file_name <- paste0(trait_name, ".EUR.sumstats.txt.gz")
format_name <- paste0("sumstats/", trait_name, "_sumstats.txt")
# Out:
#    Trait        PMID
# 1  Angina       31427789
# 2  BMI          31427789
# 3  Depression   29942085
# 4  Hair         31427789
# 5  HBP          31427789
# 6  Height       31427789
# 7  Income       31427789
# 8  Intelligence 31427789
# 9  MDD          31427789
# 10 Tanning      31427789
#    Description
# 1  Vascular/heart problems diagnosed by doctor: Angina
# 2  Body Mass Index
# 3  Depressive symptoms
# 4  Hair colour (natural, before greying): Black
# 5  Vascular/heart problems diagnosed by doctor: High blood pressure
# 6  Standing height
# 7  Average total household income before tax
# 8  Fluid intelligence test - Fluid intelligence score
# 9  Diagnoses - secondary ICD10: F32 Major depressive disorder, single episode
# 10 Ease of skin tanning
#  [1] "Angina"       "BMI"          "Depression"   "Hair"         "HBP"
#  [6] "Height"       "Income"       "Intelligence" "MDD"          "Tanning"

# %%
# Download HapMap 3 data from Broad Institute
# wget https://data.broadinstitute.org/alkesgroup/LDSCORE/eur_w_ld_chr.tar.bz2
# read in HapMap 3 data
w_hm3.snplist <- readr::read_delim("w_hm3.snplist.bz2",  "\t",
                                   escape_double = F, trim_ws = T, progress = T)

# load MHC region SNPs, CHR = 6 & BP > 28000000 & BP < 34000000
data(snps_mhc)
# Out:
# Rows: 1217311 Columns: 3
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (3): SNP, A1, A2
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# format sumstats data

Angina_sumstats <- format_sumstats(file_name[1],
                                   snps_merge = w_hm3.snplist,
                                   snps_mhc = snps_mhc,
                                   snp_col = "SNPID_UKB",
                                   or_col = "OR",
                                   se_col = "SE",
                                   freq_col = "MAF_UKB",
                                   a1_col = "A1",
                                   a2_col = "A2",
                                   p_col = "P",
                                   n_col = "NMISS",
                                   info_col = "INFO_UKB")
write_delim(Angina_sumstats, format_name[1])
rm(Angina_sumstats)

# BMI_sumstats <- format_sumstats(file_name[2],
#                                 snps_merge = w_hm3.snplist,
#                                 snps_mhc = snps_mhc,
#                                 snp_col = "SNPID_UKB",
#                                 beta_col = "BETA",
#                                 se_col = "SE",
#                                 freq_col = "MAF_UKB",
#                                 a1_col = "A1",
#                                 a2_col = "A2",
#                                 p_col = "P",
#                                 n_col = "NMISS",
#                                 info_col = "INFO_UKB")
# write_delim(BMI_sumstats, format_name[2])
# rm(BMI_sumstats)

# Depression_sumstats <- format_sumstats(file_name[3],
#                                        snps_merge = w_hm3.snplist,
#                                        snps_mhc = snps_mhc,
#                                        snp_col = "RSID",
#                                        freq_col = "MAF_UKB",
#                                        a1_col = "A1",
#                                        a2_col = "A2",
#                                        z_col = "Z",
#                                        p_col = "P",
#                                        n_col = "N",
#                                        info_col = "INFO_UKB")
# write_delim(Depression_sumstats, format_name[3])
# rm(Depression_sumstats)

# Hair_sumstats <- format_sumstats(file_name[4],
#                                  snps_merge = w_hm3.snplist,
#                                  snps_mhc = snps_mhc,
#                                  snp_col = "SNPID_UKB",
#                                  or_col = "OR",
#                                  se_col = "SE",
#                                  freq_col = "MAF_UKB",
#                                  a1_col = "A1",
#                                  a2_col = "A2",
#                                  p_col = "P",
#                                  n_col = "NMISS",
#                                  info_col = "INFO_UKB")
# write_delim(Hair_sumstats, format_name[4])
# rm(Hair_sumstats)

# HBP_sumstats <- format_sumstats(file_name[5],
#                                 snps_merge = w_hm3.snplist,
#                                 snps_mhc = snps_mhc,
#                                 snp_col = "SNPID_UKB",
#                                 or_col = "OR",
#                                 se_col = "SE",
#                                 freq_col = "MAF_UKB",
#                                 a1_col = "A1",
#                                 a2_col = "A2",
#                                 p_col = "P",
#                                 n_col = "NMISS",
#                                 info_col = "INFO_UKB")
# write_delim(HBP_sumstats, format_name[5])
# rm(HBP_sumstats)

# Height_sumstats <- format_sumstats(file_name[6],
#                                    snps_merge = w_hm3.snplist,
#                                    snps_mhc = snps_mhc,
#                                    snp_col = "SNPID_UKB",
#                                    beta_col = "BETA",
#                                    se_col = "SE",
#                                    freq_col = "MAF",
#                                    a1_col = "A1",
#                                    a2_col = "A2",
#                                    p_col = "P",
#                                    n_col = "NMISS",
#                                    info_col = "INFO_UKB")
# write_delim(Height_sumstats, format_name[6])
# rm(Height_sumstats)

# Income_sumstats <- format_sumstats(file_name[7],
#                                    snps_merge = w_hm3.snplist,
#                                    snps_mhc = snps_mhc,
#                                    snp_col = "SNPID_UKB",
#                                    beta_col = "BETA",
#                                    se_col = "SE",
#                                    freq_col = "MAF",
#                                    a1_col = "A1",
#                                    a2_col = "A2",
#                                    p_col = "P",
#                                    n_col = "NMISS",
#                                    info_col = "INFO_UKB")
# write_delim(Income_sumstats, format_name[7])
# rm(Income_sumstats)

# Intelligence_sumstats <- format_sumstats(file_name[8],
#                                          snps_merge = w_hm3.snplist,
#                                          snps_mhc = snps_mhc,
#                                          snp_col = "SNPID_UKB",
#                                          beta_col = "BETA",
#                                          se_col = "SE",
#                                          freq_col = "MAF",
#                                          a1_col = "A1",
#                                          a2_col = "A2",
#                                          p_col = "P",
#                                          n_col = "NMISS",
#                                          info_col = "INFO_UKB")
# write_delim(Intelligence_sumstats, format_name[8])
# rm(Intelligence_sumstats)

# MDD_sumstats <- format_sumstats(file_name[9],
#                                 snps_merge = w_hm3.snplist,
#                                 snps_mhc = snps_mhc,
#                                 snp_col = "SNPID_UKB",
#                                 or_col = "OR",
#                                 se_col = "SE",
#                                 freq_col = "MAF",
#                                 a1_col = "A1",
#                                 a2_col = "A2",
#                                 p_col = "P",
#                                 n_col = "NMISS",
#                                 info_col = "INFO_UKB")
# write_delim(MDD_sumstats, format_name[9])
# rm(MDD_sumstats)

# Tanning_sumstats <- format_sumstats(file_name[10],
#                                     snps_merge = w_hm3.snplist,
#                                     snps_mhc = snps_mhc,
#                                     snp_col = "SNPID_UKB",
#                                     or_col = "BETA",
#                                     se_col = "SE",
#                                     freq_col = "MAF",
#                                     a1_col = "A1",
#                                     a2_col = "A2",
#                                     p_col = "P",
#                                     n_col = "NMISS",
#                                     info_col = "INFO_UKB")
# write_delim(Tanning_sumstats, format_name[10])
# rm(Tanning_sumstats)
# Out:
# Begin reading in summary statistics data...
#
# Rows: 10599054 Columns: 20
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (7): SNP, A1, TEST, A2, SNPID_UKB, A1_UKB, A2_UKB
# dbl (13): CHR, BP, NMISS, OR, SE, L95, U95, STAT, P, MAF, NCHROBS, INFO_UKB,...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# Begin formatting...
#
# The raw data set has 10599054 lines.
#
# Remove missing data..., remaining 10599054 SNPs.
#
# Merge the data with the HapMap 3 SNPs list by SNP..., remaining 1164043 SNPs.
#
# Remove SNPs in MHC region..., remaining 1162691 SNPs.
#
# Remove SNPs with imputation INFO less than 0.9 (keeping NAs)..., remaining 1162691 SNPs.
#
# Remove the SNPs whose effect allele has the value that is not A/C/T/G...., remaining 1162691 SNPs.
#
# Remove the SNPs whose non effect allele has the value that is not A/C/T/G...., remaining 1162691 SNPs.
#
# Remove ambiguous SNPs..., remaining 1162487 SNPs.
#
# Remove duplicated SNPs..., remaining 1162487 SNPs.
#
# Infer effect size column from log(OR)...
#
# Remove SNPs with allele frequency less than min_freq (keeping NAs)..., remaining 1038652 SNPs.
#
# Remove SNPs with p-value < 0 or p-value > 1..., remaining 1038652 SNPs.
#
# Infer z-score from p-value and effect size.
#
# Remove missing values..., remaining 1038652 SNPs.
#
# Remove SNPs with sample size 5 standard deviations away from the mean..., remaining 1038652 SNPs.
#
# Remove SNPs with chi-square > chi2_max..., remaining 1038652 SNPs.
#
# The formatted data has 1038652 lines.
